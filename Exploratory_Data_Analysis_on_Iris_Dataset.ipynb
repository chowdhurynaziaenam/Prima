# %% [markdown]
# <a href="https://colab.research.google.com/github/chowdhurynaziaenam/Prima/blob/master/Exploratory_Data_Analysis_on_Iris_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Reading the CSV file
df = pd.read_csv("Iris.csv")

# Printing top 10 rows
df.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#checking missing values
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
data = df.drop_duplicates(subset ="Species",)
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 50    51            7.0           3.2            4.7           1.4
# 100  101            6.3           3.3            6.0           2.5
#
#              Species
# 0        Iris-setosa
# 50   Iris-versicolor
# 100   Iris-virginica

# %%
df.value_counts("Species")

from matplotlib import pyplot as plt
import seaborn as sns
data.groupby('Species').size().plot(kind='bar', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.show()

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# defining colors for each species
colors = {'Iris-setosa':'red', 'Iris-versicolor':'green', 'Iris-virginica':'blue'}
sns.countplot(x='Species', data=df, palette=colors, hue='Species', legend=False)
plt.show()

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt


fig, axes = plt.subplots(2, 2, figsize=(10,10))

axes[0,0].set_title("Sepal Length")
axes[0,0].hist(df['SepalLengthCm'], bins=7)

axes[0,1].set_title("Sepal Width")
axes[0,1].hist(df['SepalWidthCm'], bins=5);

axes[1,0].set_title("Petal Length")
axes[1,0].hist(df['PetalLengthCm'], bins=6);

axes[1,1].set_title("Petal Width")
axes[1,1].hist(df['PetalWidthCm'], bins=6);

# %%
#comparing petal length and petal width
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt


sns.scatterplot(x='PetalLengthCm', y='PetalWidthCm', hue='Species', data=df, )

# Placing Legend outside the Figure
plt.legend(bbox_to_anchor=(1, 1), loc=2)

plt.show()

# %% [markdown]
# From the above plot, it can be said that
# 1. Versicolor Species lies in the middle of other two species both in terms of petal length and petal width.
# 2. Species Virginica has the largest of petal lengths and widths.
# 3. Species Setosa has relatively smaller petal lengths and widths.

# %%
#comparing sepal length and sepal width
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm',hue='Species', data=df, )

# placing legend outside figure
plt.legend(bbox_to_anchor=(1, 1), loc=2)

plt.show()

# %% [markdown]
# From the above plot, it can be said that
#
# 1. Species Virginica has comparatively larger sepal lengths but smaller sepal widths.
# 2. Versicolor Species lies in the middle of other two species in terms of both sepal length and width.
# 3. Species Setosa has smaller sepal lengths but relatively larger sepal widths.

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt


sns.pairplot(df.drop(['Id'], axis = 1), hue='Species', height=2)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot for SepalLengthCm
plot = sns.FacetGrid(df, hue="Species")
plot.map(sns.histplot, "SepalLengthCm", kde=True).add_legend()

# Plot for SepalWidthCm
plot = sns.FacetGrid(df, hue="Species")
plot.map(sns.histplot, "SepalWidthCm", kde=True).add_legend()

# Plot for PetalLengthCm
plot = sns.FacetGrid(df, hue="Species")
plot.map(sns.histplot, "PetalLengthCm", kde=True).add_legend()

# Plot for PetalWidthCm
plot = sns.FacetGrid(df, hue="Species")
plot.map(sns.histplot, "PetalWidthCm", kde=True).add_legend()

plt.show()

# %%
data.select_dtypes(include=['number']).corr(method='pearson')
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.624413     -0.654654       0.969909
# SepalLengthCm  0.624413       1.000000     -0.999226       0.795795
# SepalWidthCm  -0.654654      -0.999226      1.000000      -0.818999
# PetalLengthCm  0.969909       0.795795     -0.818999       1.000000
# PetalWidthCm   0.999685       0.643817     -0.673417       0.975713
#
#                PetalWidthCm
# Id                 0.999685
# SepalLengthCm      0.643817
# SepalWidthCm      -0.673417
# PetalLengthCm      0.975713
# PetalWidthCm       1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Id'].plot(kind='hist', bins=20, title='Id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt


sns.heatmap(df.select_dtypes(include=['number']).corr(method='pearson').drop(['Id'], axis=1).drop(['Id'], axis=0), cmap='magma', annot = True);

plt.show()

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

def graph(y):
	sns.boxplot(x="Species", y=y, data=df)

plt.figure(figsize=(10,20))

# Adding the subplot at the specified
# grid position
plt.subplot(411)
graph('SepalLengthCm')

plt.subplot(412)
graph('SepalWidthCm')

plt.subplot(413)
graph('PetalLengthCm')

plt.subplot(414)
graph('PetalWidthCm')


plt.show()

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('Iris.csv')

sns.boxplot(x='SepalWidthCm',data=df)
plt.show()

# %%
import numpy as np

# Load the dataset
df = pd.read_csv('Iris.csv')

# IQR
Q1 = np.percentile(df['SepalWidthCm'], 25,interpolation = 'midpoint')

Q3 = np.percentile(df['SepalWidthCm'], 75,interpolation = 'midpoint')
IQR = Q3 - Q1

print("Previous Shape: ", df.shape)

# Upper bound
upperbound = np.where(df['SepalWidthCm'] >= (Q3+1.5*IQR))

# Lower bound
lowerbound = np.where(df['SepalWidthCm'] <= (Q1-1.5*IQR))

# Removing the Outliers
df.drop(upperbound[0], inplace = True)
df.drop(lowerbound[0], inplace = True)

print("New Shape: ", df.shape)

sns.boxplot(x='SepalWidthCm', data=df)
plt.show()
# Out:
# Previous Shape:  (150, 6)
# New Shape:  (146, 6)
